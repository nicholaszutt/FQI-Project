# %%
from qiskit import *

# %%
c = QuantumCircuit(3,3)
c.h(0)
c.cx(0,1)
c.cx(0,2)
c.barrier()
c.measure([0,1,2],[0,1,2])
c.draw(output='mpl')

# %%
#simulate on qiskit aer
sim = Aer.get_backend('qasm_simulator')
res = execute(c, backend = sim, shots = 2000).result()

#writing something to plot the simulation results on a histogram
from qiskit.tools.visualization import plot_histogram
plot_histogram(res.get_counts(c))

# %%
counts = res.get_counts(c)
print(counts)
# Out:
# {'111': 976, '000': 1024}

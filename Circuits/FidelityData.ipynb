# %%
import numpy as np
from matplotlib import pyplot as plt

Swap_Melbourne = [
    [0.9994571775831872, 0.860525299630127, 0.6960769946622414, 0.7180348500438553],
    [0.9959363202490377, 0.7046620141103919, 0.7136619970374181, 0.7986947216612544],
    [0.9996907315332295, 0.6968564540635406, 0.6613065371133967, 0.7470829200507342],
    [1.0015214379872792, 0.7621774552762609, 0.72705133212759, 0.8511633518629332],
    [1.0012990644349764, 0.7160822079298108, 0.6738587245667309, 0.7555527480182438],
    [1.0005136700279529, 0.6956044685449752, 0.5968686035986626, 0.6810157252133693],
    [1.0005932858138098, 0.7040074502682102, 0.6680719130116959, 0.7509129957825373],
    [0.9967380863665359, 0.7243495530065552, 0.7224890976001346, 0.826777572150156],
    [1.0011592904911264, 0.7564190074628857, 0.7677136581273835, 0.8256533074922083],
    [0.9985897795340106, 0.7762932845602806, 0.7138915116049207, 0.8219555318528959],
    [1.0000746075415285, 0.774177876949807, 0.6735624020132268, 0.7401583392913409],
    [0.9924028479611241, 0.7741646224788996, 0.6067422607044598, 0.7628013747433708],
    [1.0027393954643657, 0.7844227975602818, 0.6061846776220496, 0.78689706212886],
    [1.0044893867080111, 0.7723453057818072, 0.7125105343101268, 0.8074481508233233],
    [1.0018861138393145, 0.7966716653688652, 0.6901250584866899, 0.7664058994162171]
]

Swap_Burlington = [
    [1.001253360314278, 0.7893501561546383, 0.5569413778627778, 0.6156984912242829],
    [1.0002977119770424, 0.8252469016544052, 0.6250729839110692, 0.7233182551087596],
    [0.9975685032963744, 0.759782520742115, 0.5659033492281575, 0.6449086050199259],
    [0.9981225536225375, 0.7735790786244597, 0.3677048570953796, 0.5529292132167245],
    [0.9985184081288434, 0.7867354440970984, 0.5308365491098518, 0.6182186891654349],
    [1.000633891987302, 0.7752929814119384, 0.5285789473864986, 0.6526456779799347],
    [1.0005519253841253, 0.8005039862301953, 0.5449887955776711, 0.6376588585229434],
    [1.0018193725694573, 0.7821369600689712, 0.524746456710514, 0.5807240623848098],
    [1.0002477755626502, 0.819352797876933, 0.5700757961337724, 0.6520571130726001],
    [0.9956084946455299, 0.7929391955976923, 0.5251153917328357, 0.6124915325758341],
    [0.998797623361193, 0.7638808953721643, 0.44972133657037, 0.5136462275960055],
    [0.9999416512932211, 0.7638538791753011, 0.41464837203353194, 0.5256048401515299],
    [0.9999828489569592, 0.786827498731126, 0.4610490521234432, 0.5216884669058071],
    [1.002787396696074, 0.8491008536486896, 0.6433419832870707, 0.6932438334259293],
    [0.9995772620773461, 0.798199867403182, 0.40528925271781735, 0.47254532490958034]
]

Swap_IBMQX2 = [
    [1.0006686538583056, 0.8950724367441758, 0.817747490390404, 0.8699053633555827],
    [0.9982869463956846, 0.87840704277767, 0.7452441825931767, 0.7890607903868934],
    [1.0057182923141388, 0.8593439836751031, 0.7487426221562887, 0.7958028288883483],
    [1.0048272966893594, 0.878463826048397, 0.7133409945496665, 0.7497074284152847],
    [0.9965754524502365, 0.8612014807698585, 0.7285652850035745, 0.7679887332712747],
    [1.0046453328613436, 0.8593589064472009, 0.7119229543473684, 0.7541189553991025],
    [1.0003855265609172, 0.9144767840201389, 0.8020852023025565, 0.8520056335298154],
    [1.0016626177883357, 0.8530717010088146, 0.726538485653923, 0.7739062675598454],
    [0.9997723200005623, 0.8539909167543411, 0.6893400720395222, 0.7367642910769873],
    [1.0000611745849466, 0.8970356841007979, 0.7219428869729423, 0.758498535242873],
    [1.000417915541199, 0.8929216506226991, 0.7176572277873264, 0.758921835981004],
    [0.9998620805024498, 0.9281909267011125, 0.7533290715604247, 0.7785181418036368],
    [0.9988539573160062, 0.8852054835340615, 0.6888010710076836, 0.7293310516133342],
    [0.9999907984072747, 0.8910416054143779, 0.7372573001401431, 0.7854183759935622],
    [0.999552881745873, 0.8866263910939961, 0.7277809458633302, 0.7697575239986169],
]

Swap_Mel = np.mean(Swap_Melbourne, axis=0)
Swap_Burl = np.mean(Swap_Burlington, axis=0)
Swap_X2 = np.mean(Swap_IBMQX2, axis=0)

Swap_Mel_err = np.std(Swap_Melbourne, axis=0)
Swap_Burl_err = np.std(Swap_Burlington, axis=0)
Swap_X2_err = np.std(Swap_IBMQX2, axis=0)

print('Swap Fidelities')
print('The Melbourne fidelities are:', Swap_Mel)
print('The Burlington fidelities are:', Swap_Burl)
print('The IBMQX2 fidelities are:', Swap_X2)
# Out:
# Swap Fidelities
# The Melbourne fidelities are: [0.99980608 0.75325063 0.68200769 0.77603697]
# The Burlington fidelities are: [0.99971392 0.79111887 0.51426763 0.60115861]
# The IBMQX2 fidelities are: [1.00075208 0.88229392 0.73535305 0.77798038]

# %%
width = 0.25
r1 = np.arange(len(Swap_Mel))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

plt.bar(r1, Swap_X2, width=width, label='Yorktown', yerr=Swap_X2_err)
plt.bar(r2, Swap_Mel, width=width, label='Melbourne', yerr=Swap_Mel_err)
plt.bar(r3, Swap_Burl, width=width, label='Burlington', yerr=Swap_Burl_err)

plt.title('Entanglement Swapping Fidelities for 3 Devices')
plt.xticks([r + width for r in range(4)], ['Simulator', 'Noisy Simulator', 'Device', 'Calibrated Device'])
plt.ylabel('Fidelity')
plt.ylim(0,1.3)

plt.legend()
# plt.savefig('../report/images/swap_histogram.pdf')
plt.show()

# %%
Tele_Melbourne = [
    [0.996396554503962, 0.781098992007038, 0.796847841083988, 0.861105915901553],
    [1.001010523975380, 0.772881632823713, 0.777255006060623, 0.841134426201356],
    [1.002967691538480, 0.770205411907927, 0.842844784234861, 0.905337634933176],
    [0.996648317417638, 0.770149815925316, 0.803752660724108, 0.978251354344011],
    [0.998447826904051, 0.784877536260994, 0.754848614753752, 0.854271144079881],
    [1.008020900627070, 0.773923674578628, 0.680800997697452, 0.724582528148222],
    [1.001307189329830, 0.755245748028795, 0.745968236132601, 0.809483821433516],
    [0.996012421088261, 0.763727377132487, 0.695095630298172, 0.748084660390800],
    [0.999999112245965, 0.781324214101791, 0.824021695724342, 0.916586609859742],
    [0.998350309905660, 0.773239760758497, 0.784701877638021, 0.880081936298337],
    [1.004949381152820, 0.787453908276878, 0.760304429456173, 0.803308994538791],
    [1.004155034238270, 0.766016417401935, 0.780388214277567, 0.827036413662965],
    [1.001044853690870, 0.765099194958401, 0.786823569526480, 0.990457377563206],
    [0.998842573714713, 0.781181016197905, 0.754499044003996, 0.821031091886012],
    [1.003939186920230, 0.763483852545172, 0.784427092676142, 0.874211313451049]
]

Tele_Burlington = [
    [1.002016205289860, 0.917266021069371, 0.670870521630040, 0.688826563225858],
    [1.001921806437520, 0.900268322015564, 0.776214779345027, 0.808644702116891],
    [0.997687236936904, 0.860194579260650, 0.680801501074675, 0.703871424198725],
    [0.998424034030763, 0.907640807284057, 0.718825699618349, 0.745010610438531],
    [1.000190822954410, 0.898666179630748, 0.768169455270991, 0.798677023565475],
    [1.002652461231930, 0.862551721715472, 0.505446921894581, 0.506027039124793],
    [0.995216450256573, 0.882578725543566, 0.721520157205994, 0.740923114319294],
    [1.000009893296660, 0.919301426345444, 0.779290016996041, 0.805446074258269],
    [0.997149167492420, 0.883405026451351, 0.703372477790877, 0.721002498913956],
    [0.995964631256511, 0.914155533147258, 0.753847007278432, 0.780003323610586],
    [1.007808557540120, 0.899063670533556, 0.787123502193729, 0.820179102259116],
    [0.997154949525395, 0.916355365213885, 0.759854980824439, 0.784342750673052],
    [0.998104865967602, 0.904249095586766, 0.723389641512657, 0.743117731345669],
    [0.996135439063372, 0.881013628196886, 0.743445842250786, 0.765766036742862],
    [0.999032999555787, 0.904806062139530, 0.752171029057002, 0.774860801654521]
]

Tele_IBMQX2 = [
    [1.000378278117810, 0.919137154117403, 0.849739417771456, 0.885490976539240],
    [1.000612542620710, 0.931269910289208, 0.855710857223087, 0.893861369517001],
    [0.997774993570473, 0.934709880018569, 0.874119544566002, 0.912474319045078],
    [0.995054458123757, 0.946976606888780, 0.832296216388912, 0.866301635559170],
    [0.999310778142077, 0.946299461384439, 0.846636879939559, 0.880803180966188],
    [1.005389321252170, 0.935823609888459, 0.855058476482821, 0.894471965735033],
    [0.998839817576880, 0.919399122281924, 0.836139048966680, 0.871901420013512],
    [1.006682500919820, 0.943867356858645, 0.916405923659863, 0.959931550425941],
    [1.003244850747100, 0.947470227235064, 0.854392689221556, 0.891317550896749],
    [1.002041375078670, 0.945426889209066, 0.857691785336305, 0.898383617888585],
    [0.999527838120663, 0.948276713477186, 0.835753345928656, 0.870598768463981],
    [0.999570163427006, 0.947324051052692, 0.845485167292662, 0.880955613347443],
    [1.001709041751390, 0.938597765148667, 0.848644513611208, 0.885789464830043],
    [1.002495182787830, 0.928697526675852, 0.864331805146948, 0.905283110671663],
    [1.003571421249340, 0.920971582078847, 0.843625294707835, 0.880222653372943]
]

Tele_Mel = np.mean(Tele_Melbourne, axis=0)
Tele_Burl = np.mean(Tele_Burlington, axis=0)
Tele_X2 = np.mean(Tele_IBMQX2, axis=0)

Tele_Mel_err = np.std(Tele_Melbourne, axis=0)
Tele_Burl_err = np.std(Tele_Burlington, axis=0)
Tele_X2_err = np.std(Tele_IBMQX2, axis=0)

print('Teleportation Fidelities')
print('The Melbourne fidelities are:', Tele_Mel)
print('The Burlington fidelities are:', Tele_Burl)
print('The IBMQX2 fidelities are:', Tele_X2)
# Out:
# Teleportation Fidelities
# The Melbourne fidelities are: [1.00080613 0.77266057 0.77150531 0.85566435]
# The Burlington fidelities are: [0.99929797 0.89676774 0.72295624 0.74577992]
# The IBMQX2 fidelities are: [1.00108017 0.93694986 0.85440206 0.89185248]

# %%
width = 0.25
r1 = np.arange(len(Swap_Mel))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

plt.bar(r1, Tele_X2, width=width, label='Yorktown', yerr=Tele_X2_err)
plt.bar(r2, Tele_Mel, width=width, label='Melbourne', yerr=Tele_Mel_err)
plt.bar(r3, Tele_Burl, width=width, label='Burlington', yerr=Tele_Burl_err)

plt.title('Teleportation Fidelities for 3 Devices')
plt.xticks([r + width for r in range(4)], ['Simulator', 'Noisy Simulator', 'Device', 'Calibrated Device'])
plt.ylabel('Fidelity')
plt.ylim(0,1.3)

plt.legend()
# plt.savefig('../report/images/teleport_histogram.pdf')
plt.show()

# %%
Grov_Melbourne = [
    [1.0, 0.749864467854711, 0.736979503400520, 0.813371443399042],
    [1.0, 0.856608072916667, 0.781168619791667, 0.892607132495675],
    [1.0, 0.767159700152927, 0.784750995299350, 0.891898887562228],
    [1.0, 0.868916829427083, 0.852844238281250, 0.895977221970917],
    [1.0, 0.925944010416667, 0.950256347656250, 0.964022379594573],
    [1.0, 0.863627115885417, 0.848551432291667, 0.897892239362163],
    [1.0, 0.911376953125000, 0.908081054687500, 0.983775977154709],
    [1.0, 0.846761067708333, 0.826232910156250, 0.944854858805223],
    [1.0, 0.914001464843750, 0.889099121093750, 0.948766708050703],
    [1.0, 0.850158691406250, 0.790527343750000, 0.924910188580811],
    [1.0, 0.871154785156250, 0.842407226562500, 0.898552919079784],
    [1.0, 0.921976725260417, 0.949096679687500, 0.959150817938704],
    [1.0, 0.922566731770833, 0.947387695312500, 0.959712607109393],
    [1.0, 0.866210937500000, 0.869995117187500, 0.930906948280213],
    [1.0, 0.855428059895833, 0.776102701822917, 0.911473429637119],
]

Grov_Burlington = [
    [1.0, 0.894938151041667, 0.621439615885416, 0.800195218903775],
    [1.0, 0.897237141927083, 0.602152506510417, 0.790974755685015],
    [1.0, 0.865600585937500, 0.507181803385416, 0.711587085827107],
    [1.0, 0.863260904947917, 0.553710937500000, 0.750998748414800],
    [1.0, 0.863240559895833, 0.558756510416666, 0.765429078131864],
    [1.0, 0.903116861979167, 0.635986328125000, 0.676582508180160],
    [1.0, 0.897115071614583, 0.500122070312500, 0.890147791496418],
    [1.0, 0.904520670572917, 0.543111165364583, 0.622251740541714],
    [1.0, 0.907287597656250, 0.626098632812500, 0.717573094033951],
    [1.0, 0.864176432291667, 0.661254882812500, 0.753075174689724],
    [1.0, 0.899149576822917, 0.642272949218750, 0.801017598159856],
    [1.0, 0.900716145833333, 0.641988118489583, 0.806910971135179],
    [1.0, 0.867919921875000, 0.648111979166666, 0.731170623782903],
    [1.0, 0.903584798177083, 0.617797851562500, 0.752313633811858],
    [1.0, 0.897725423177083, 0.596781412760417, 0.752148217039892],
]

Grov_IBMQX2 = [
    [1.0, 0.967142740885417, 0.914184570312500, 0.967246301661881],
    [1.0, 0.910380045572917, 0.914367675781250, 0.965938179591105],
    [1.0, 0.908304850260417, 0.913085937500000, 0.965591509745019],
    [1.0, 0.967936197916667, 0.913431803385417, 0.969076066812122],
    [1.0, 0.969136555989583, 0.916809082031250, 0.966691324269627],
    [1.0, 0.919698079427083, 0.762634277343750, 0.777774781489334],
    [1.0, 0.909566243489583, 0.898620605468750, 0.970101681140198],
    [1.0, 0.920389811197917, 0.761372884114583, 0.777716529554805],
    [1.0, 0.921305338541667, 0.757303873697917, 0.777836372812485],
    [1.0, 0.920593261718750, 0.758890787760417, 0.777345602965476],
    [1.0, 0.921488444010417, 0.799092610677083, 0.815022024431638],
    [1.0, 0.966308593750000, 0.873881022135417, 0.923598778704249],
    [1.0, 0.910481770833333, 0.875996907552083, 0.934613885180291],
    [1.0, 0.919718424479167, 0.700663248697916, 0.709863677387320],
    [1.0, 0.969156901041667, 0.873575846354167, 0.923696766743574],
]

Grov_Mel = np.mean(Grov_Melbourne, axis=0)
Grov_Burl = np.mean(Grov_Burlington, axis=0)
Grov_X2 = np.mean(Grov_IBMQX2, axis=0)

Grov_Mel_err = np.std(Grov_Melbourne, axis=0)
Grov_Burl_err = np.std(Grov_Burlington, axis=0)
Grov_X2_err = np.std(Grov_IBMQX2, axis=0)

print('Grover Fidelities')
print('The Melbourne fidelities are:', Grov_Mel)
print('The Burlington fidelities are:', Grov_Burl)
print('The IBMQX2 fidelities are:', Grov_X2)
# Out:
# Grover Fidelities
# The Melbourne fidelities are: [1.         0.86611704 0.85023207 0.92119158]
# The Burlington fidelities are: [1.         0.88863932 0.59711778 0.75482508]
# The IBMQX2 fidelities are: [1.         0.93344048 0.84226074 0.88147423]

# %%
width = 0.25
r1 = np.arange(len(Swap_Mel))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

plt.bar(r1, Grov_X2, width=width, label='Yorktown', yerr=Grov_X2_err)
plt.bar(r2, Grov_Mel, width=width, label='Melbourne', yerr=Grov_Mel_err)
plt.bar(r3, Grov_Burl, width=width, label='Burlington', yerr=Grov_Burl_err)

plt.title('Grover Algorithm Fidelities for 3 Devices')
plt.xticks([r + width for r in range(4)], ['Simulator', 'Noisy Simulator', 'Device', 'Calibrated Device'])
plt.ylabel('Fidelity')
plt.ylim(0,1.3)

plt.legend()
# plt.savefig('../report/images/grover_histogram.pdf')
plt.show()

# %%
Puri_Melbourne = [
    [1.0, 0.7455060597865085, 0.3851167611349542, 0.40359771745121464],
    [1.0, 0.7408283582602257, 0.4523745756564512, 0.4786199529898965],
    [1.0, 0.7410612035545581, 0.4115693982406378, 0.43396729688914126],
    [1.0, 0.7440328230164627, 0.471265372558476, 0.5003139766422895],
    [1.0, 0.7425998510365797, 0.47558251117565997, 0.5117487078397877],
    [1.0, 0.7495420274425193, 0.5002945912467947, 0.546123407783892],
    [1.0, 0.7250217136709858, 0.4821080539830541, 0.5127217009353813],
    [1.0, 0.736858606430908, 0.4694833569222536, 0.5055661889008347],
    [1.0, 0.7540350571494185, 0.4308183385965898, 0.4531132683993077],
    [1.0, 0.7337095789678157, 0.4855715142155466, 0.5277971439059432],
    [1.0, 0.7308630756303915, 0.4829342246620898, 0.5223140313961019],
    [1.0, 0.7584239731973781, 0.4616510964939501, 0.4944853367903802],
    [1.0, 0.7267892794577311, 0.48401682284018344, 0.5172621814753865],
    [1.0, 0.7627499287774726, 0.44158165502236113, 0.4718283326765832],
    [1.0, 0.7572641719156854, 0.49019431126731194, 0.5342991732815334],
]

Puri_Burlington = [
    [1.0, 0.832336032288692, 0.576125230433633, 0.726788853321212],
    [1.0, 0.841979797315705, 0.626123340211255, 0.778556325660213],
    [1.0, 0.846444170775707,0.596435790490913, 0.807525098820266],
    [1.0, 0.841478247202338, 0.538998898126766, 0.757035678160326],
    [1.0, 0.858676992596491, 0.547762643493576, 0.722903923490953],
    [1.0, 0.853189787011688, 0.591734973549702, 0.764406478578295],
    [1.0, 0.857056299586125, 0.615526224319454, 0.828271929237671],
    [1.0, 0.846858512876384, 0.607706230782877, 0.806357587046416],
    [1.0, 0.8391821593926, 0.584437891502591, 0.763196910516572],
    [1.0, 0.809161620680119, 0.646167141948549, 0.84758176049802],
    [1.0, 0.823422164614695, 0.62903087129607, 0.838553874695012],
    [1.0, 0.889571396703903, 0.65408017522183, 0.827293841287289],
    [1.0, 0.827989537731397, 0.621166485758584, 0.798954081406654],
    [1.0, 0.856515796592144, 0.573829672655433, 0.723074525116385],
    [1.0, 0.840349634119602, 0.503142056935641, 0.680931418403635],
]

Puri_IBMQX2 = [
    [1.0, 0.886669845737357, 0.83159173718476, 0.89579465656812],
    [1.0, 0.868620183679743, 0.837858441050575, 0.900368631680831],
    [1.0, 0.876763114891913, 0.838188990612469, 0.906935195251975],
    [1.0, 0.884533227514701, 0.833532807650287, 0.904346977286546],
    [1.0, 0.888850952222482, 0.815614609798422, 0.877123442854192],
    [1.0, 0.881197795145422, 0.836725062769721, 0.901562618322617],
    [1.0, 0.87106023103507, 0.828195759924313, 0.902701330195238],
    [1.0, 0.882707132191395, 0.831980323938737, 0.89915853559449],
    [1.0, 0.89207301772021, 0.823416106921703, 0.886237093243096],
    [1.0, 0.866321645480022, 0.813842931136487, 0.87594290705022],
    [1.0, 0.885639511625827, 0.828089572314662, 0.898397445704764],
    [1.0, 0.892279469325333, 0.831137378636534, 0.898294931839131],
    [1.0, 0.882931279336644, 0.836585143968795, 0.905686179349001],
    [1.0, 0.883970863843374, 0.833678021418781, 0.902040382420695],
    [1.0, 0.880371127781035, 0.84558438558185, 0.917058669745018],
]

Puri_Mel = np.mean(Puri_Melbourne, axis=0)
Puri_Burl = np.mean(Puri_Burlington, axis=0)
Puri_X2 = np.mean(Puri_IBMQX2, axis=0)

Puri_Mel_err = np.std(Puri_Melbourne, axis=0)
Puri_Burl_err = np.std(Puri_Burlington, axis=0)
Puri_X2_err = np.std(Puri_IBMQX2, axis=0)

print('Purification Fidelities')
print('The Melbourne fidelities are:', Puri_Mel)
print('The Burlington fidelities are:', Puri_Burl)
print('The IBMQX2 fidelities are:', Puri_X2)
# Out:
# Purification Fidelities
# The Melbourne fidelities are: [1.         0.74328571 0.46163751 0.49425056]
# The Burlington fidelities are: [1.         0.84428081 0.59415118 0.77809549]
# The IBMQX2 fidelities are: [1.         0.88159929 0.83106808 0.89810993]

# %%
width = 0.25
r1 = np.arange(len(Puri_Mel))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

plt.bar(r1, Puri_X2, width=width, label='Yorktown', yerr=Puri_X2_err)
plt.bar(r2, Puri_Mel, width=width, label='Melbourne', yerr=Puri_Mel_err)
plt.bar(r3, Puri_Burl, width=width, label='Burlington', yerr=Puri_Burl_err)

plt.title('Purification Fidelities for 3 Devices')
plt.xticks([r + width for r in range(4)], ['Simulator', 'Noisy Simulator', 'Device', 'Calibrated Device'])
plt.ylabel('Fidelity')
plt.ylim(0,1.3)

plt.legend()
# plt.savefig('../report/images/purification_histogram.pdf')
plt.show()

# %% [markdown]
# ### All simulator fidelities are well within statistical error of 1.

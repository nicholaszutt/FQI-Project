# %%
import numpy as np

Swap_Melbourne = [
    [0.9994571775831872, 0.860525299630127, 0.6960769946622414, 0.7180348500438553],
    [0.9959363202490377, 0.7046620141103919, 0.7136619970374181, 0.7986947216612544],
    [0.9996907315332295, 0.6968564540635406, 0.6613065371133967, 0.7470829200507342],
    [1.0015214379872792, 0.7621774552762609, 0.72705133212759, 0.8511633518629332],
    [1.0012990644349764, 0.7160822079298108, 0.6738587245667309, 0.7555527480182438],
    [1.0005136700279529, 0.6956044685449752, 0.5968686035986626, 0.6810157252133693],
    [1.0005932858138098, 0.7040074502682102, 0.6680719130116959, 0.7509129957825373],
    [0.9967380863665359, 0.7243495530065552, 0.7224890976001346, 0.826777572150156],
    [1.0011592904911264, 0.7564190074628857, 0.7677136581273835, 0.8256533074922083],
    [0.9985897795340106, 0.7762932845602806, 0.7138915116049207, 0.8219555318528959]
]

Swap_Burlington = [
    [1.001253360314278, 0.7893501561546383, 0.5569413778627778, 0.6156984912242829],
    [1.0002977119770424, 0.8252469016544052, 0.6250729839110692, 0.7233182551087596],
    [0.9975685032963744, 0.759782520742115, 0.5659033492281575, 0.6449086050199259],
    [0.9981225536225375, 0.7735790786244597, 0.3677048570953796, 0.5529292132167245],
    [0.9985184081288434, 0.7867354440970984, 0.5308365491098518, 0.6182186891654349],
    [1.000633891987302, 0.7752929814119384, 0.5285789473864986, 0.6526456779799347],
    [1.0005519253841253, 0.8005039862301953, 0.5449887955776711, 0.6376588585229434],
    [1.0018193725694573, 0.7821369600689712, 0.524746456710514, 0.5807240623848098],
    [1.0002477755626502, 0.819352797876933, 0.5700757961337724, 0.6520571130726001],
    [0.9956084946455299, 0.7929391955976923, 0.5251153917328357, 0.6124915325758341]
]

Swap_IBMQX2 = [
    [1.0006686538583056, 0.8950724367441758, 0.817747490390404, 0.8699053633555827],
    [0.9982869463956846, 0.87840704277767, 0.7452441825931767, 0.7890607903868934],
    [1.0057182923141388, 0.8593439836751031, 0.7487426221562887, 0.7958028288883483],
    [1.0048272966893594, 0.878463826048397, 0.7133409945496665, 0.7497074284152847],
    [0.9965754524502365, 0.8612014807698585, 0.7285652850035745, 0.7679887332712747],
    [1.0046453328613436, 0.8593589064472009, 0.7119229543473684, 0.7541189553991025],
    [1.0003855265609172, 0.9144767840201389, 0.8020852023025565, 0.8520056335298154],
    [1.0016626177883357, 0.8530717010088146, 0.726538485653923, 0.7739062675598454],
    [0.9997723200005623, 0.8539909167543411, 0.6893400720395222, 0.7367642910769873],
    [1.0000611745849466, 0.8970356841007979, 0.7219428869729423, 0.758498535242873],
]

Swap_Mel = np.mean(Swap_Melbourne, axis=0)
Swap_Burl = np.mean(Swap_Burlington, axis=0)
Swap_X2 = np.mean(Swap_IBMQX2, axis=0)

print('The Melbourne fidelities are:', Swap_Mel)
print('The Burlington fidelities are:', Swap_Burl)
print('The IBMQX2 fidelities are:', Swap_X2)
# Out:
# The Melbourne fidelities are: [0.99954988 0.73969772 0.69409904 0.77768437]
# The Burlington fidelities are: [0.9994622  0.790492   0.53399645 0.62906505]
# The IBMQX2 fidelities are: [1.00126036 0.87504228 0.74054702 0.78477588]

# %%
err_bar = 1/np.sqrt(81920)
print('The statistical error for 8192 shots is:', err_bar)
print('The possible values of the Simulator Fidelity \
range from {} to {}'.format(Swap_Mel[0]+err_bar,Swap_Mel[0]-err_bar))
# The simulator fidelity is within statistical error of 1, as expected.
# Out:
# The statistical error for 8192 shots is: 0.0034938562148434213
# The possible values of the Simulator Fidelity range from 1.003043740616958 to 0.9960560281872711

# %% [markdown]
# ### All simulator fidelities are well within statistical error of 1.
